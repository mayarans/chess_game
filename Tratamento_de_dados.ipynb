# %% [markdown]
# <a href="https://colab.research.google.com/github/mayarans/chess_game/blob/master/Tratamento_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df= pd.read_csv('/content/drive/My Drive/acidentes2022_todas_causas_tipos.csv',sep=';',encoding = 'unicode_escape')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519023 entries, 0 to 519022
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      519023 non-null  int64
#  1   pesid                   472415 non-null  float64
#  2   data_inversa            519023 non-null  object
#  3   dia_semana              519023 non-null  object
#  4   horario                 519023 non-null  object
#  5   uf                      519023 non-null  object
#  6   br                      517052 non-null  float64
#  7   km                      517052 non-null  object
#  8   municipio               519023 non-null  object
#  9   causa_principal         519023 non-null  object
#  10  causa_acidente          519023 non-null  object
#  11  ordem_tipo_acidente     519023 non-null  int64
#  12  tipo_acidente           519023 non-null  object
#  13  classificacao_acidente  519023 non-null  object
# ...

# %%
a = df[df['causa_principal']=="Não"]
a[['causa_principal','causa_acidente']]
# Out:
#        causa_principal                            causa_acidente
# 10                 Não  Reação tardia ou ineficiente do condutor
# 11                 Não  Reação tardia ou ineficiente do condutor
# 12                 Não  Reação tardia ou ineficiente do condutor
# 13                 Não  Reação tardia ou ineficiente do condutor
# 14                 Não  Reação tardia ou ineficiente do condutor
# ...                ...                                       ...
# 518988             Não                        Pista Escorregadia
# 518989             Não                        Pista Escorregadia
# 518990             Não                        Pista Escorregadia
# 518991             Não                        Pista Escorregadia
# 518992             Não                        Pista Escorregadia
#
# [221658 rows x 2 columns]

# %%
df.head()
# Out:
#        id     pesid data_inversa dia_semana   horario  uf     br   km  \
# 0  405147  911178.0   2022-01-01     sábado  00:10:00  CE  222.0  2,8
# 1  405147  911179.0   2022-01-01     sábado  00:10:00  CE  222.0  2,8
# 2  405149  912796.0   2022-01-01     sábado  01:30:00  PE  104.0   63
# 3  405149  912793.0   2022-01-01     sábado  01:30:00  PE  104.0   63
# 4  405149  913204.0   2022-01-01     sábado  01:30:00  PE  104.0   63
#
#    municipio causa_principal  ...           sexo  ilesos feridos_leves  \
# 0  FORTALEZA             Sim  ...      Masculino       1             0
# 1  FORTALEZA             Sim  ...      Masculino       0             0
# 2    CARUARU             Sim  ...       Feminino       0             1
# 3    CARUARU             Sim  ...      Masculino       0             0
# 4    CARUARU             Sim  ...  Não Informado       0             0
#
#   feridos_graves mortos     latitude     longitude regional delegacia  \
# ...
